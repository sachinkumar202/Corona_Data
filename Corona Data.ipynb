# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('latest Covid-19 India Status1.csv')

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Deaths  \
# 0                                Maharashtra      6122893  117869  123857
# 1                                     Kerala      3011694  108400   14108
# 2                                  Karnataka      2862338   39626   35601
# 3                                 Tamil Nadu      2506848   34076   33196
# 4                             Andhra Pradesh      1911231   32356   12919
# 5                              Uttar Pradesh      1706934    1947   22666
# 6                                West Bengal      1508223   16655   17850
# 7                                      Delhi      1434780     858   25005
# 8                               Chhattisgarh       996689    5017   13464
# 9                                  Rajasthan       952887     935    8942
# 10                                    Odisha       929788   25148    4358
# 11                                   Gujarat       824029    1969   10072
# 12                            Madhya Pradesh       790070     441    9019
# 13                                   Haryana       769093    1066    9515
# 14                                     Bihar       722850    1183    9612
# 15                                 Telengana       629054   11472    3710
# 16                                    Punjab       596970    1964   16141
# 17                                     Assam       524556   23371    4743
# 18                                 Jharkhand       346113     532    5118
# 19                               Uttarakhand       340959    1506    7338
# 20                         Jammu and Kashmir       317761   34391    4349
# 21                          Himachal Pradesh       203117    1338    3486
# 22                                       Goa       168015    1950    3082
# 23                                Puducherry       118416    1753    1765
# 24                                   Manipur        74341    6534    1229
# 25                                   Tripura        69019    4122     703
# 26                                Chandigarh        61780      99     809
# 27                                 Meghalaya        52712    4229     886
# 28                         Arunachal Pradesh        38283    3363     184
# 29                                  Nagaland        25663    1070     505
# 30                                   Mizoram        22703    3960     100
# 31                                    Sikkim        21573    1975     311
# 32                                    Ladakh        20143     183     204
# 33  Dadra and Nagar Haveli and Daman and Diu        10576      38       4
# 34                               Lakshadweep         9965     246      49
# 35                       Andaman and Nicobar         7491      14     128
#
#     Active Ratio (%)  Death Ratio (%)
# 0               1.93             2.02
# 1               3.60             0.47
# 2               1.38             1.24
# 3               1.36             1.32
# 4               1.69             0.68
# 5               0.11             1.33
# 6               1.10             1.18
# 7               0.06             1.74
# 8               0.50             1.35
# 9               0.10             0.94
# 10              2.70             0.47
# 11              0.24             1.22
# 12              0.06             1.14
# 13              0.14             1.24
# 14              0.16             1.33
# 15              1.82             0.59
# 16              0.33             2.70
# 17              4.46             0.90
# 18              0.15             1.48
# 19              0.44             2.15
# 20              1.08             1.37
# 21              0.66             1.72
# 22              1.16             1.83
# 23              1.48             1.49
# 24              8.79             1.65
# 25              5.97             1.02
# 26              0.16             1.31
# 27              8.02             1.68
# 28              8.78             0.48
# 29              4.17             1.97
# 30             17.44             0.44
# 31              9.15             1.44
# 32              0.91             1.01
# 33              0.36             0.04
# 34              2.47             0.49
# 35              0.19             1.71

# %%
df.head()
# Out:
#         State/UTs  Total Cases  Active  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6122893  117869  123857              1.93
# 1          Kerala      3011694  108400   14108              3.60
# 2       Karnataka      2862338   39626   35601              1.38
# 3      Tamil Nadu      2506848   34076   33196              1.36
# 4  Andhra Pradesh      1911231   32356   12919              1.69
#
#    Death Ratio (%)
# 0             2.02
# 1             0.47
# 2             1.24
# 3             1.32
# 4             0.68

# %%
df.shape
# Out:
# (36, 6)

# %%
(117869/6122893)*100
# Out:
# 1.9250540553297273

# %%
df.tail()
# Out:
#                                    State/UTs  Total Cases  Active  Deaths  \
# 31                                    Sikkim        21573    1975     311
# 32                                    Ladakh        20143     183     204
# 33  Dadra and Nagar Haveli and Daman and Diu        10576      38       4
# 34                               Lakshadweep         9965     246      49
# 35                       Andaman and Nicobar         7491      14     128
#
#     Active Ratio (%)  Death Ratio (%)
# 31              9.15             1.44
# 32              0.91             1.01
# 33              0.36             0.04
# 34              2.47             0.49
# 35              0.19             1.71

# %%
df.shape
# Out:
# (36, 6)

# %%
# Active=(df['Active']/df['Total Cases'])*100
# Active
# (117869/6122893)*100
# (34076/2506848)*100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UTs         36 non-null     object
#  1   Total Cases       36 non-null     int64
#  2   Active            36 non-null     int64
#  3   Deaths            36 non-null     int64
#  4   Active Ratio (%)  36 non-null     float64
#  5   Death Ratio (%)   36 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.8+ KB

# %%
df.isnull().sum()
# Out:
# State/UTs           0
# Total Cases         0
# Active              0
# Deaths              0
# Active Ratio (%)    0
# Death Ratio (%)     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Deaths', 'Active Ratio (%)',
#        'Death Ratio (%)'],
#       dtype='object')

# %%
df.columns = ['State', 'Total_Cases', 'Active', 'Deaths', 'Active_Ratio', 'Death_Ratio']

# %%
df.head()
# Out:
#             State  Total_Cases  Active  Deaths  Active_Ratio  Death_Ratio
# 0     Maharashtra      6122893  117869  123857          1.93         2.02
# 1          Kerala      3011694  108400   14108          3.60         0.47
# 2       Karnataka      2862338   39626   35601          1.38         1.24
# 3      Tamil Nadu      2506848   34076   33196          1.36         1.32
# 4  Andhra Pradesh      1911231   32356   12919          1.69         0.68

# %%
df.groupby(['State'])['Active_Ratio'].agg(['max']).sort_values(by='max',ascending=False)
# Out:
#                                             max
# State
# Mizoram                                   17.44
# Sikkim                                     9.15
# Manipur                                    8.79
# Arunachal Pradesh                          8.78
# Meghalaya                                  8.02
# Tripura                                    5.97
# Assam                                      4.46
# Nagaland                                   4.17
# Kerala                                     3.60
# Odisha                                     2.70
# Lakshadweep                                2.47
# Maharashtra                                1.93
# Telengana                                  1.82
# Andhra Pradesh                             1.69
# Puducherry                                 1.48
# Karnataka                                  1.38
# Tamil Nadu                                 1.36
# Goa                                        1.16
# West Bengal                                1.10
# Jammu and Kashmir                          1.08
# Ladakh                                     0.91
# Himachal Pradesh                           0.66
# Chhattisgarh                               0.50
# Uttarakhand                                0.44
# Dadra and Nagar Haveli and Daman and Diu   0.36
# Punjab                                     0.33
# Gujarat                                    0.24
# Andaman and Nicobar                        0.19
# Chandigarh                                 0.16
# Bihar                                      0.16
# Jharkhand                                  0.15
# Haryana                                    0.14
# Uttar Pradesh                              0.11
# Rajasthan                                  0.10
# Delhi                                      0.06
# Madhya Pradesh                             0.06

# %%
plt.figure(figsize=(10,4))
plt.plot(df['State'],df['Active_Ratio'],color='red',marker='o')
plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5)
plt.xlabel('State', fontsize=15)

plt.ylabel('Active Ration', fontsize=15)
plt.title("Line Plot for Active Ratio",fontsize=15)
plt.show()

# %%
'''  Toatal Cases in each state'''
total_cases_state = df.groupby('State')['Total_Cases'].sum().sort_values(ascending=False)
total_cases_state
# Out:
# State
# Maharashtra                                 6122893
# Kerala                                      3011694
# Karnataka                                   2862338
# Tamil Nadu                                  2506848
# Andhra Pradesh                              1911231
# Uttar Pradesh                               1706934
# West Bengal                                 1508223
# Delhi                                       1434780
# Chhattisgarh                                 996689
# Rajasthan                                    952887
# Odisha                                       929788
# Gujarat                                      824029
# Madhya Pradesh                               790070
# Haryana                                      769093
# Bihar                                        722850
# Telengana                                    629054
# Punjab                                       596970
# Assam                                        524556
# Jharkhand                                    346113
# Uttarakhand                                  340959
# Jammu and Kashmir                            317761
# Himachal Pradesh                             203117
# Goa                                          168015
# Puducherry                                   118416
# Manipur                                       74341
# Tripura                                       69019
# Chandigarh                                    61780
# Meghalaya                                     52712
# Arunachal Pradesh                             38283
# Nagaland                                      25663
# Mizoram                                       22703
# Sikkim                                        21573
# Ladakh                                        20143
# Dadra and Nagar Haveli and Daman and Diu      10576
# Lakshadweep                                    9965
# Andaman and Nicobar                            7491
# Name: Total_Cases, dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(15, 8));
plt.xticks(rotation=75)
sns.barplot(total_cases_state.index, total_cases_state);
plt.title('Total Cases in Each State', fontsize=20);
plt.xlabel('State', fontsize=30)
plt.ylabel('Total Cases', fontsize=15);

# %%
1*(10**6)*6
# Out:
# 6000000

# %% [markdown]
# *Maharashtra has the highest number of total cases in India, Kerala and Karnataka rank second and third although there is not much difference between their total counts. *

# %%
''' top 10 states Total Cases '''
top_10 = total_cases_state[:10]
plt.figure(figsize=(15, 8));
plt.xticks(rotation=90)
sns.barplot(top_10.index, top_10.values);
plt.title('Top 10 States Total Cases', fontsize=20);
plt.xlabel('State', fontsize=15)
plt.ylabel('Total Cases', fontsize=15);

# %%
top_10 = total_cases_state[:10]

# %%
top_10
# Out:
# State
# Maharashtra       6122893
# Kerala            3011694
# Karnataka         2862338
# Tamil Nadu        2506848
# Andhra Pradesh    1911231
# Uttar Pradesh     1706934
# West Bengal       1508223
# Delhi             1434780
# Chhattisgarh       996689
# Rajasthan          952887
# Name: Total_Cases, dtype: int64

# %%
''' pie chart of active cases in top 5 states in india'''
plt.figure(figsize=(8,8))
labels = df.index
plt.pie(x='Active', data=df.head(), labels='State',autopct='%.0f%%')
plt.title("Active Cases in Top 5 states in India", fontsize = 24) 
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df['State'],df['Active_Ratio'],color='red',marker='o',label='Active cases')
plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5)
plt.xlabel('State', fontsize=15)

plt.ylabel('Active Ratio', fontsize=15)
plt.title("Line Plot for Active Ratio",fontsize=15)

plt.plot(df['State'],df['Death_Ratio'],color='blue',marker='*',label='death')
plt.legend()
plt.show()

# %%
''' pie chart of total cases in top 5 states in India '''
plt.figure(figsize=(7,7))
labels = df.index
plt.pie(x='Total_Cases', data=df.head(), labels='State', startangle=90,autopct='%.1f%%')
plt.title("Total Cases in Top 5 states in India", fontsize = 24) 
plt.tight_layout() 
plt.show()

# %%
df
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 0                                Maharashtra      6122893  117869  123857
# 1                                     Kerala      3011694  108400   14108
# 2                                  Karnataka      2862338   39626   35601
# 3                                 Tamil Nadu      2506848   34076   33196
# 4                             Andhra Pradesh      1911231   32356   12919
# 5                              Uttar Pradesh      1706934    1947   22666
# 6                                West Bengal      1508223   16655   17850
# 7                                      Delhi      1434780     858   25005
# 8                               Chhattisgarh       996689    5017   13464
# 9                                  Rajasthan       952887     935    8942
# 10                                    Odisha       929788   25148    4358
# 11                                   Gujarat       824029    1969   10072
# 12                            Madhya Pradesh       790070     441    9019
# 13                                   Haryana       769093    1066    9515
# 14                                     Bihar       722850    1183    9612
# 15                                 Telengana       629054   11472    3710
# 16                                    Punjab       596970    1964   16141
# 17                                     Assam       524556   23371    4743
# 18                                 Jharkhand       346113     532    5118
# 19                               Uttarakhand       340959    1506    7338
# 20                         Jammu and Kashmir       317761   34391    4349
# 21                          Himachal Pradesh       203117    1338    3486
# 22                                       Goa       168015    1950    3082
# 23                                Puducherry       118416    1753    1765
# 24                                   Manipur        74341    6534    1229
# 25                                   Tripura        69019    4122     703
# 26                                Chandigarh        61780      99     809
# 27                                 Meghalaya        52712    4229     886
# 28                         Arunachal Pradesh        38283    3363     184
# 29                                  Nagaland        25663    1070     505
# 30                                   Mizoram        22703    3960     100
# 31                                    Sikkim        21573    1975     311
# 32                                    Ladakh        20143     183     204
# 33  Dadra and Nagar Haveli and Daman and Diu        10576      38       4
# 34                               Lakshadweep         9965     246      49
# 35                       Andaman and Nicobar         7491      14     128
#
#     Active_Ratio  Death_Ratio
# 0           1.93         2.02
# 1           3.60         0.47
# 2           1.38         1.24
# 3           1.36         1.32
# 4           1.69         0.68
# 5           0.11         1.33
# 6           1.10         1.18
# 7           0.06         1.74
# 8           0.50         1.35
# 9           0.10         0.94
# 10          2.70         0.47
# 11          0.24         1.22
# 12          0.06         1.14
# 13          0.14         1.24
# 14          0.16         1.33
# 15          1.82         0.59
# 16          0.33         2.70
# 17          4.46         0.90
# 18          0.15         1.48
# 19          0.44         2.15
# 20          1.08         1.37
# 21          0.66         1.72
# 22          1.16         1.83
# 23          1.48         1.49
# 24          8.79         1.65
# 25          5.97         1.02
# 26          0.16         1.31
# 27          8.02         1.68
# 28          8.78         0.48
# 29          4.17         1.97
# 30         17.44         0.44
# 31          9.15         1.44
# 32          0.91         1.01
# 33          0.36         0.04
# 34          2.47         0.49
# 35          0.19         1.71

# %%
''' pie chart of total cases in top 5 states in India '''
plt.figure(figsize=(7,7))
labels = df.index
plt.pie(x='Total_Cases', data=df.tail(15), labels='State', startangle=90,autopct='%.1f%%')
plt.title("Total Cases in Top 5 states in India", fontsize = 24) 
plt.tight_layout() 
plt.show()

# %%
df.head()
# Out:
#             State  Total_Cases  Active  Deaths  Active_Ratio  Death_Ratio  \
# 0     Maharashtra      6122893  117869  123857          1.93         2.02
# 1          Kerala      3011694  108400   14108          3.60         0.47
# 2       Karnataka      2862338   39626   35601          1.38         1.24
# 3      Tamil Nadu      2506848   34076   33196          1.36         1.32
# 4  Andhra Pradesh      1911231   32356   12919          1.69         0.68
#
#    Recovered_Cases
# 0          5881167
# 1          2889186
# 2          2787111
# 3          2439576
# 4          1865956

# %%
''' caculating Recovered_Cases '''
recovered_cases = df['Total_Cases'] - (df['Active'] + df['Deaths'])

# %%
''' adding it to df '''
df['Recovered_Cases'] = recovered_cases

# %%
df
# Out:
#                                        State  Total_Cases  Active  Deaths  \
# 0                                Maharashtra      6122893  117869  123857
# 1                                     Kerala      3011694  108400   14108
# 2                                  Karnataka      2862338   39626   35601
# 3                                 Tamil Nadu      2506848   34076   33196
# 4                             Andhra Pradesh      1911231   32356   12919
# 5                              Uttar Pradesh      1706934    1947   22666
# 6                                West Bengal      1508223   16655   17850
# 7                                      Delhi      1434780     858   25005
# 8                               Chhattisgarh       996689    5017   13464
# 9                                  Rajasthan       952887     935    8942
# 10                                    Odisha       929788   25148    4358
# 11                                   Gujarat       824029    1969   10072
# 12                            Madhya Pradesh       790070     441    9019
# 13                                   Haryana       769093    1066    9515
# 14                                     Bihar       722850    1183    9612
# 15                                 Telengana       629054   11472    3710
# 16                                    Punjab       596970    1964   16141
# 17                                     Assam       524556   23371    4743
# 18                                 Jharkhand       346113     532    5118
# 19                               Uttarakhand       340959    1506    7338
# 20                         Jammu and Kashmir       317761   34391    4349
# 21                          Himachal Pradesh       203117    1338    3486
# 22                                       Goa       168015    1950    3082
# 23                                Puducherry       118416    1753    1765
# 24                                   Manipur        74341    6534    1229
# 25                                   Tripura        69019    4122     703
# 26                                Chandigarh        61780      99     809
# 27                                 Meghalaya        52712    4229     886
# 28                         Arunachal Pradesh        38283    3363     184
# 29                                  Nagaland        25663    1070     505
# 30                                   Mizoram        22703    3960     100
# 31                                    Sikkim        21573    1975     311
# 32                                    Ladakh        20143     183     204
# 33  Dadra and Nagar Haveli and Daman and Diu        10576      38       4
# 34                               Lakshadweep         9965     246      49
# 35                       Andaman and Nicobar         7491      14     128
#
#     Active_Ratio  Death_Ratio  Recovered_Cases
# 0           1.93         2.02          5881167
# 1           3.60         0.47          2889186
# 2           1.38         1.24          2787111
# 3           1.36         1.32          2439576
# 4           1.69         0.68          1865956
# 5           0.11         1.33          1682321
# 6           1.10         1.18          1473718
# 7           0.06         1.74          1408917
# 8           0.50         1.35           978208
# 9           0.10         0.94           943010
# 10          2.70         0.47           900282
# 11          0.24         1.22           811988
# 12          0.06         1.14           780610
# 13          0.14         1.24           758512
# 14          0.16         1.33           712055
# 15          1.82         0.59           613872
# 16          0.33         2.70           578865
# 17          4.46         0.90           496442
# 18          0.15         1.48           340463
# 19          0.44         2.15           332115
# 20          1.08         1.37           279021
# 21          0.66         1.72           198293
# 22          1.16         1.83           162983
# 23          1.48         1.49           114898
# 24          8.79         1.65            66578
# 25          5.97         1.02            64194
# 26          0.16         1.31            60872
# 27          8.02         1.68            47597
# 28          8.78         0.48            34736
# 29          4.17         1.97            24088
# 30         17.44         0.44            18643
# 31          9.15         1.44            19287
# 32          0.91         1.01            19756
# 33          0.36         0.04            10534
# 34          2.47         0.49             9670
# 35          0.19         1.71             7349

# %%
rec_cases = df.groupby('State')['Recovered_Cases'].sum().sort_values(ascending=False)
rec_cases
# Out:
# State
# Maharashtra                                 5881167
# Kerala                                      2889186
# Karnataka                                   2787111
# Tamil Nadu                                  2439576
# Andhra Pradesh                              1865956
# Uttar Pradesh                               1682321
# West Bengal                                 1473718
# Delhi                                       1408917
# Chhattisgarh                                 978208
# Rajasthan                                    943010
# Odisha                                       900282
# Gujarat                                      811988
# Madhya Pradesh                               780610
# Haryana                                      758512
# Bihar                                        712055
# Telengana                                    613872
# Punjab                                       578865
# Assam                                        496442
# Jharkhand                                    340463
# Uttarakhand                                  332115
# Jammu and Kashmir                            279021
# Himachal Pradesh                             198293
# Goa                                          162983
# Puducherry                                   114898
# Manipur                                       66578
# Tripura                                       64194
# Chandigarh                                    60872
# Meghalaya                                     47597
# Arunachal Pradesh                             34736
# Nagaland                                      24088
# Ladakh                                        19756
# Sikkim                                        19287
# Mizoram                                       18643
# Dadra and Nagar Haveli and Daman and Diu      10534
# Lakshadweep                                    9670
# Andaman and Nicobar                            7349
# Name: Recovered_Cases, dtype: int64

# %%
''' plotting recovered cases on barplot '''
plt.figure(figsize=(15, 8));
plt.xticks(rotation=90)
sns.barplot(rec_cases.index, rec_cases);
plt.title('Total Recovered Cases in Each State', fontsize=20);
plt.xlabel('State', fontsize=15)
plt.ylabel('Total Recovered Cases', fontsize=15);

# %%
plt.figure(figsize=(10,10))
plt.plot(df['State'],df['Total_Cases'],color='red',marker='*',label='Total_cases')
plt.plot(df['State'],df['Recovered_Cases'],color='cyan',marker='+',label='recover')

plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
# here 1e6=======1*(10**6)*6

# %%
''' looking at top 10 States Recovered cases '''
rec_cases = rec_cases[:10]
plt.figure(figsize=(15, 8));
plt.xticks(rotation=90)
sns.barplot(rec_cases.index, rec_cases);
plt.title('Top 10 States Recovered Cases', fontsize=20);
plt.xlabel('State', fontsize=15)
plt.ylabel('Recovered Cases', fontsize=15);

# %%
df[['State','Total_Cases','Recovered_Cases']]
# Out:
#                                        State  Total_Cases  Recovered_Cases
# 0                                Maharashtra      6122893          5881167
# 1                                     Kerala      3011694          2889186
# 2                                  Karnataka      2862338          2787111
# 3                                 Tamil Nadu      2506848          2439576
# 4                             Andhra Pradesh      1911231          1865956
# 5                              Uttar Pradesh      1706934          1682321
# 6                                West Bengal      1508223          1473718
# 7                                      Delhi      1434780          1408917
# 8                               Chhattisgarh       996689           978208
# 9                                  Rajasthan       952887           943010
# 10                                    Odisha       929788           900282
# 11                                   Gujarat       824029           811988
# 12                            Madhya Pradesh       790070           780610
# 13                                   Haryana       769093           758512
# 14                                     Bihar       722850           712055
# 15                                 Telengana       629054           613872
# 16                                    Punjab       596970           578865
# 17                                     Assam       524556           496442
# 18                                 Jharkhand       346113           340463
# 19                               Uttarakhand       340959           332115
# 20                         Jammu and Kashmir       317761           279021
# 21                          Himachal Pradesh       203117           198293
# 22                                       Goa       168015           162983
# 23                                Puducherry       118416           114898
# 24                                   Manipur        74341            66578
# 25                                   Tripura        69019            64194
# 26                                Chandigarh        61780            60872
# 27                                 Meghalaya        52712            47597
# 28                         Arunachal Pradesh        38283            34736
# 29                                  Nagaland        25663            24088
# 30                                   Mizoram        22703            18643
# 31                                    Sikkim        21573            19287
# 32                                    Ladakh        20143            19756
# 33  Dadra and Nagar Haveli and Daman and Diu        10576            10534
# 34                               Lakshadweep         9965             9670
# 35                       Andaman and Nicobar         7491             7349
